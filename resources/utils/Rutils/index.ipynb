# %%
# install.packages("devtools")

# %% [markdown]
# ### Create new package files (if needed)

# %%
# usethis::create_package("myrutils")
# setwd("myrutils")
# usethis::use_r("index")
# setwd("../")

# %%
# getwd()

# %% [markdown]
# ### Document, build, and check R package

# %%
setwd("myrutils")
devtools::check()
devtools::build()
setwd("../")

# Copy a built package from the source directory to the destination directory
# file.copy(from = "myrutils_0.1.0.tar.gz", to = "../../docs/pyr")
# Out:
# ══ Documenting ═════════════════════════════════════════════════════════════════
# ℹ Updating myrutils documentation
# ℹ Loading myrutils
# Writing NAMESPACE
# Writing NAMESPACE
# ══ Building ════════════════════════════════════════════════════════════════════
# Setting env vars:
# • CFLAGS    : -Wall -pedantic -fdiagnostics-color=always
# • CXXFLAGS  : -Wall -pedantic -fdiagnostics-color=always
# • CXX11FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX14FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX17FLAGS: -Wall -pedantic -fdiagnostics-color=always
# • CXX20FLAGS: -Wall -pedantic -fdiagnostics-color=always
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-new-workspace\resources\utils\Rutils\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
#
# ══ Checking ════════════════════════════════════════════════════════════════════
# Setting env vars:
# • _R_CHECK_CRAN_INCOMING_REMOTE_               : FALSE
# • _R_CHECK_CRAN_INCOMING_                      : FALSE
# • _R_CHECK_FORCE_SUGGESTS_                     : FALSE
# • _R_CHECK_PACKAGES_USED_IGNORE_UNUSED_IMPORTS_: FALSE
# • NOT_CRAN                                     : true
# ── R CMD check ─────────────────────────────────────────────────────────────────
# * using log directory 'C:/Users/jayan/AppData/Local/Temp/Rtmp4eF7JY/file22c42e5134fd/myrutils.Rcheck'
# * using R version 4.3.1 (2023-06-16 ucrt)
# * using platform: x86_64-w64-mingw32 (64-bit)
# * R was compiled by
#     gcc.exe (GCC) 12.2.0
#     GNU Fortran (GCC) 12.2.0
# * running under: Windows 11 x64 (build 23601)
# * using session charset: UTF-8
# * using options '--no-manual --as-cran'
# * checking for file 'myrutils/DESCRIPTION' ... OK
# * this is package 'myrutils' version '0.1.0'
# * package encoding: UTF-8
# * checking package namespace information ... OK
# * checking package dependencies ... OK
# * checking if this is a source package ... OK
# * checking if there is a namespace ... OK
# * checking for executable files ... OK
# * checking for hidden files and directories ... OK
# * checking for portable file names ... OK
# * checking serialization versions ... OK
# * checking whether package 'myrutils' can be installed ... OK
# * checking installed package size ... OK
# * checking package directory ... OK
# * checking for future file timestamps ... OK
# * checking DESCRIPTION meta-information ... NOTE
# License components which are templates and need '+ file LICENSE':
#   MIT
# * checking top-level files ... OK
# * checking for left-over files ... OK
# * checking index information ... OK
# * checking package subdirectories ... OK
# * checking R files for non-ASCII characters ... OK
# * checking R files for syntax errors ... OK
# * checking whether the package can be loaded ... OK
# * checking whether the package can be loaded with stated dependencies ... OK
# * checking whether the package can be unloaded cleanly ... OK
# * checking whether the namespace can be loaded with stated dependencies ... OK
# * checking whether the namespace can be unloaded cleanly ... OK
# * checking dependencies in R code ... OK
# * checking S3 generic/method consistency ... OK
# * checking replacement functions ... OK
# * checking foreign function calls ... OK
# * checking R code for possible problems ... NOTE
# get_likert_plot: no visible binding for global variable 'Frequency'
# get_likert_plot: no visible binding for global variable 'Ratio'
# get_likert_plot: no visible binding for global variable 'Marker'
# get_likert_plot: no visible binding for global variable 'Response'
# Undefined global functions or variables:
#   Frequency Marker Ratio Response
# * checking Rd files ... OK
# * checking Rd metadata ... OK
# * checking Rd line widths ... OK
# * checking Rd cross-references ... OK
# * checking for missing documentation entries ... OK
# * checking for code/documentation mismatches ... OK
# * checking Rd \usage sections ... OK
# * checking Rd contents ... OK
# * checking for unstated dependencies in examples ... OK
# * checking examples ... OK
# * checking for non-standard things in the check directory ... OK
# * checking for detritus in the temp directory ... OK
# * DONE
#
# Status: 2 NOTEs
# See
#   'C:/Users/jayan/AppData/Local/Temp/Rtmp4eF7JY/file22c42e5134fd/myrutils.Rcheck/00check.log'
# for details.
# ── R CMD check results ───────────────────────────────────── myrutils 0.1.0 ────
# Duration: 26.7s
#
# ❯ checking DESCRIPTION meta-information ... NOTE
#   License components which are templates and need '+ file LICENSE':
#     MIT
#
# ❯ checking R code for possible problems ... NOTE
#   get_likert_plot: no visible binding for global variable 'Frequency'
#   get_likert_plot: no visible binding for global variable 'Ratio'
#   get_likert_plot: no visible binding for global variable 'Marker'
#   get_likert_plot: no visible binding for global variable 'Response'
#   Undefined global functions or variables:
#     Frequency Marker Ratio Response
#
# 0 errors ✔ | 0 warnings ✔ | 2 notes ✖
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-new-workspace\resources\utils\Rutils\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
# [1] "C:/Users/jayan/Documents/create-new-workspace/resources/utils/Rutils/myrutils_0.1.0.tar.gz"

# %%
# remove.packages("myrutils")

# %% [markdown]
# ### Load package from tar.gz file and test

# %%
devtools::install("myrutils")
# Out:
# cli      (3.6.1  -> 3.6.2) [CRAN]
# vctrs    (0.6.4  -> 0.6.5) [CRAN]
# rlang    (1.1.1  -> 1.1.2) [CRAN]
# fansi    (1.0.5  -> 1.0.6) [CRAN]
# processx (3.8.2  -> 3.8.3) [CRAN]
# jsonlite (1.8.7  -> 1.8.8) [CRAN]
# stringi  (1.7.12 -> 1.8.3) [CRAN]
# dplyr    (1.1.3  -> 1.1.4) [CRAN]
# Installing 8 packages: cli, vctrs, rlang, fansi, processx, jsonlite, stringi, dplyr
# package 'cli' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'cli'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\cli\libs\x64\cli.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\cli\libs\x64\cli.dll: Permission denied"
# Warning message:
# "restored 'cli'"
# package 'vctrs' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'vctrs'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\vctrs\libs\x64\vctrs.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\vctrs\libs\x64\vctrs.dll: Permission denied"
# Warning message:
# "restored 'vctrs'"
# package 'rlang' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'rlang'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\rlang\libs\x64\rlang.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\rlang\libs\x64\rlang.dll: Permission denied"
# Warning message:
# "restored 'rlang'"
# package 'fansi' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'fansi'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\fansi\libs\x64\fansi.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\fansi\libs\x64\fansi.dll: Permission denied"
# Warning message:
# "restored 'fansi'"
# package 'processx' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'processx'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\processx\libs\x64\processx.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\processx\libs\x64\processx.dll: Permission denied"
# Warning message:
# "restored 'processx'"
# package 'jsonlite' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'jsonlite'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\jsonlite\libs\x64\jsonlite.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\jsonlite\libs\x64\jsonlite.dll: Permission denied"
# Warning message:
# "restored 'jsonlite'"
# package 'stringi' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'stringi'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\stringi\libs\x64\stringi.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\stringi\libs\x64\stringi.dll: Permission denied"
# Warning message:
# "restored 'stringi'"
# package 'dplyr' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'dplyr'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\jayan\scoop\apps\r-release\4.3.1\library\00LOCK\dplyr\libs\x64\dplyr.dll to C:\Users\jayan\scoop\apps\r-release\4.3.1\library\dplyr\libs\x64\dplyr.dll: Permission denied"
# Warning message:
# "restored 'dplyr'"
# The downloaded binary packages are in
# 	C:\Users\jayan\AppData\Local\Temp\Rtmp4eF7JY\downloaded_packages
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\jayan\Documents\create-new-workspace\resources\utils\Rutils\myrutils/DESCRIPTION' ... OK
# * preparing 'myrutils':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building 'myrutils_0.1.0.tar.gz'
#
# Running "C:/Users/jayan/scoop/apps/r-release/current/bin/x64/Rcmd.exe" \
#   INSTALL \
#   "C:\Users\jayan\AppData\Local\Temp\Rtmp4eF7JY/myrutils_0.1.0.tar.gz" \
#   --install-tests
# * installing to library 'C:/Users/jayan/scoop/apps/r-release/4.3.1/library'
# * installing *source* package 'myrutils' ...
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (myrutils)

# %%
library(myrutils)

# %%
packages <- c(
    "pwr"
)
packages_check(packages)
# Out:
# Loading required package: pwr
# [[1]]
# NULL

# %%
# Cohen's effect sizes small=.02, medium=.15, large=.35 (Cohen, J. (1988). Statistical power analysis for the behavioral sciences (2nd ed.). Hillsdale, NJ: Lawrence Erlbaum)

# u is the number of coefficients in the model (i.e., number of independent + interaction variables + 1 for cutoff - b0) Therefore, u > 1

# u = 3 because b0 + ConditionC + CovariateC (e.g., ManufactuabilityC)
pwr.f2.test(u = 3, f2 = .35, sig.level = 0.05, power = 0.8)
# sample size = u + roundup(v) + 1
# Out:
#      Multiple regression power calculation
#
#               u = 3
#               v = 31.3129
#              f2 = 0.35
#       sig.level = 0.05
#           power = 0.8
